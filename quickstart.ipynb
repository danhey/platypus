# %%
from platypus import Platypus

# %%
pt = Platypus('HD 129056')
lcs = pt.correct()
# Out:
# ...
# TargetPixelFileCollection of 1 objects:
# 	HD 129056 (1 TessTargetPixelFiles) Sectors: 11
# /Users/daniel/Dropbox (Sydney Uni)/code/platypus/platypus/utils.py:37: RuntimeWarning: invalid value encountered in sqrt
#   amp = np.sqrt(sc) * fct

# %%
lc = lcs.stitch()
lc.plot()
# Out:
# /Users/daniel/anaconda3/lib/python3.7/site-packages/lightkurve/lightcurve.py:702: LightkurveWarning: The light curve already appears to be in relative units; `normalize()` will convert the light curve into relative units for a second time, which is probably not what you want.
#   LightkurveWarning)
